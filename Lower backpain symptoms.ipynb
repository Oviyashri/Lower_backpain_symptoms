# %% [markdown]
# # Lower back pain symptoms dataset

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
df=pd.read_csv("Dataset_spine.csv")
df
# Out:
#           Col1       Col2       Col3       Col4        Col5       Col6  \
# 0    63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4    49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
# ..         ...        ...        ...        ...         ...        ...
# 305  47.903565  13.616688  36.000000  34.286877  117.449062  -4.245395
# 306  53.936748  20.721496  29.220534  33.215251  114.365845  -0.421010
# 307  61.446597  22.694968  46.170347  38.751628  125.670725  -2.707880
# 308  45.252792   8.693157  41.583126  36.559635  118.545842   0.214750
# 309  33.841641   5.073991  36.641233  28.767649  123.945244  -0.199249
#
#          Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Col1         310 non-null    float64
#  1   Col2         310 non-null    float64
#  2   Col3         310 non-null    float64
#  3   Col4         310 non-null    float64
#  4   Col5         310 non-null    float64
#  5   Col6         310 non-null    float64
#  6   Col7         310 non-null    float64
#  7   Col8         310 non-null    float64
#  8   Col9         310 non-null    float64
#  9   Col10        310 non-null    float64
#  10  Col11        310 non-null    float64
#  11  Col12        310 non-null    float64
#  12  Class_att    310 non-null    object
#  13  Unnamed: 13  14 non-null     object
# dtypes: float64(12), object(2)
# memory usage: 34.0+ KB

# %%
df.describe()
# Out:
#              Col1        Col2        Col3        Col4        Col5        Col6  \
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean    60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std     17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min     26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%     46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%     58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%     72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max    129.834041   49.431864  125.742385  121.429566  163.071041  418.543082
#
#              Col7        Col8        Col9       Col10       Col11       Col12
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     0.472979   21.321526   13.064511   11.933317  -14.053139   25.645981
# ...

# %%
print("Number of Null value:",df.isnull().sum())
# Out:
# Number of Null value: Col1             0
# Col2             0
# Col3             0
# Col4             0
# Col5             0
# Col6             0
# Col7             0
# Col8             0
# Col9             0
# Col10            0
# Col11            0
# Col12            0
# Class_att        0
# Unnamed: 13    296
# dtype: int64

# %%
print(df.nunique())
# Out:
# Col1           310
# Col2           310
# Col3           280
# Col4           281
# Col5           310
# Col6           310
# Col7           310
# Col8           310
# Col9           310
# Col10          310
# Col11          310
# Col12          310
# Class_att        2
# Unnamed: 13     14
# dtype: int64

# %%
df.columns=['Pelvic_incidence','Pelvic tilt','Lumbar_lordosis_angle','Sacral_slope','Pelvic_radius','Degree_spondylolisthesis','Pelvic_slope','Direct_tilt','Thoracic_slope','Cervical_tilt','Sacrum_angle','Scoliosis_slope','Class_att','Unnamed: 13']

# %%
df=df.drop(['Unnamed: 13'],axis=1)
df
# Out:
#      Pelvic_incidence  Pelvic tilt  Lumbar_lordosis_angle  Sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      Pelvic_radius  Degree_spondylolisthesis  Pelvic_slope  Direct_tilt  \
# ...

# %%
df["Class_att"].unique()
df["Class_att"]=df["Class_att"].replace({'Abnormal':1, 'Normal':2})
print(df)
# Out:
#      Pelvic_incidence  Pelvic tilt  Lumbar_lordosis_angle  Sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      Pelvic_radius  Degree_spondylolisthesis  Pelvic_slope  Direct_tilt  \
# ...

# %%
df["Class_att"].value_counts()
# Out:
# 1    210
# 2    100
# Name: Class_att, dtype: int64

# %%
#y=df["Class_att"]
#X=df.drop(["Class_att"],axis=1)
#X

# %%
def preprocessing (df):
    df=df.copy()

# %%
#splitting
y=df["Class_att"].copy()
X=df.drop("Class_att",axis=1).copy()
X
# Out:
#      Pelvic_incidence  Pelvic tilt  Lumbar_lordosis_angle  Sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      Pelvic_radius  Degree_spondylolisthesis  Pelvic_slope  Direct_tilt  \
# ...

# %%
#scaler
scaler=StandardScaler()
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,shuffle=True,random_state=123)

# %%
X_train
# Out:
#      Pelvic_incidence  Pelvic tilt  Lumbar_lordosis_angle  Sacral_slope  \
# 148          0.305603    -0.771599              -0.059816      0.967730
# 82           1.634479     1.155567              -0.235729      1.237228
# 287         -1.595412    -1.788149              -1.773896     -0.715406
# 268         -0.194716    -0.105456              -0.490646     -0.171405
# 7           -0.879201    -0.679253              -1.235826     -0.622522
# ..                ...          ...                    ...           ...
# 106          0.262491    -0.771059               0.313370      0.911968
# 83           1.197502     0.725702               1.401206      0.996617
# 17          -1.698016    -1.440943              -1.045553     -1.106037
# 230          0.297242     0.559948               0.574994     -0.035813
# 98           0.997081     0.489396               2.265255      0.915450
#
#      Pelvic_radius  Degree_spondylolisthesis  Pelvic_slope  Direct_tilt  \
# ...

# %%
y_train
# Out:
# 148    1
# 82     1
# 287    2
# 268    2
# 7      1
#       ..
# 106    1
# 83     1
# 17     1
# 230    2
# 98     1
# Name: Class_att, Length: 217, dtype: int64

# %%
model_1=LogisticRegression()
model_1.fit(X_train,y_train)
model_1.score(X_test,y_test)
model_1.score(X_test,y_test)*100
# Out:
# 84.94623655913979

# %%
model_2=DecisionTreeClassifier()
model_2.fit(X_train,y_train)
model_2.score(X_test,y_test)
model_2.score(X_test,y_test)*100
# Out:
# 75.26881720430107

# %%
model_3=RandomForestClassifier()
model_3.fit(X_train,y_train)
model_3.score(X_test,y_test)
model_3.score(X_test,y_test)*100
# Out:
# 78.49462365591397

# %%
model_4=GradientBoostingClassifier()
model_4.fit(X_train,y_train)
model_4.score(X_test,y_test)
model_4.score(X_test,y_test)*100
# Out:
# 80.64516129032258
